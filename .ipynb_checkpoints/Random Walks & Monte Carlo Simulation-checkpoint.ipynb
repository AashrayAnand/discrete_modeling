# %%
import random

# given an initial starting point, and a gridlike city structure, conduct
# a "random walk" of n blocks, where a random walk is defined as a set of n
# random directional choices, where the walker can go in any direction, including
# backtracing
def random_walk(n):
    """return coordinates after 'n' block random walk"""
    x = 0
    y = 0
    for i in range(n):
        # choose a random direction for the next step
        step = random.choice(['N', 'S', 'E', 'W'])
        if step is 'N':
            y += 1
        elif step is 'S':
            y -= 1
        elif step is 'E':
            x += 1
        else:
            x -= 1
    return x, y

# %%
for i in range(100):
    walk = random_walk(10)
    print(walk, "distance from home = ", abs(walk[0]) + abs(walk[1]))
# Out:
# (3, 3) distance from home =  6
# (2, 0) distance from home =  2
# (1, 5) distance from home =  6
# (0, 0) distance from home =  0
# (-4, -2) distance from home =  6
# (-3, 3) distance from home =  6
# (0, 2) distance from home =  2
# (3, -1) distance from home =  4
# (1, -1) distance from home =  2
# (3, 3) distance from home =  6
# (0, -2) distance from home =  2
# (2, -2) distance from home =  4
# (3, 1) distance from home =  4
# (-1, -1) distance from home =  2
# (3, -3) distance from home =  6
# (0, 6) distance from home =  6
# (-2, 0) distance from home =  2
# (0, 4) distance from home =  4
# (0, -2) distance from home =  2
# (0, -2) distance from home =  2
# (0, -4) distance from home =  4
# (-2, 0) distance from home =  2
# (-3, 1) distance from home =  4
# (-3, -3) distance from home =  6
# (1, 1) distance from home =  2
# (3, 5) distance from home =  8
# (2, -4) distance from home =  6
# (3, 3) distance from home =  6
# (2, 0) distance from home =  2
# (0, 2) distance from home =  2
# (-2, 0) distance from home =  2
# (-3, -1) distance from home =  4
# (1, 3) distance from home =  4
# (-2, 2) distance from home =  4
# (-1, -1) distance from home =  2
# (3, -1) distance from home =  4
# (0, -2) distance from home =  2
# (1, -3) distance from home =  4
# (4, 0) distance from home =  4
# (-2, -2) distance from home =  4
# (2, 2) distance from home =  4
# (0, 2) distance from home =  2
# (2, 2) distance from home =  4
# (-1, -3) distance from home =  4
# (2, 0) distance from home =  2
# (-1, -1) distance from home =  2
# (2, 2) distance from home =  4
# (-3, -1) distance from home =  4
# (0, 2) distance from home =  2
# (2, 0) distance from home =  2
# (4, -2) distance from home =  6
# (-2, -4) distance from home =  6
# (1, 3) distance from home =  4
# (4, -4) distance from home =  8
# (1, 1) distance from home =  2
# (0, 0) distance from home =  0
# (3, -1) distance from home =  4
# (-2, -2) distance from home =  4
# (2, 2) distance from home =  4
# (1, 1) distance from home =  2
# (-1, 3) distance from home =  4
# (0, 2) distance from home =  2
# (0, 4) distance from home =  4
# (0, 0) distance from home =  0
# (3, -1) distance from home =  4
# (3, 1) distance from home =  4
# (1, 1) distance from home =  2
# (1, 1) distance from home =  2
# (3, -1) distance from home =  4
# (3, 1) distance from home =  4
# (2, -2) distance from home =  4
# (-1, 3) distance from home =  4
# (0, 0) distance from home =  0
# (1, -5) distance from home =  6
# (-2, 2) distance from home =  4
# (-4, 4) distance from home =  8
# (3, 1) distance from home =  4
# (1, 3) distance from home =  4
# (1, 1) distance from home =  2
# (-2, -4) distance from home =  6
# (-1, 3) distance from home =  4
# (4, 0) distance from home =  4
# (4, 0) distance from home =  4
# (-4, 0) distance from home =  4
# (1, 1) distance from home =  2
# (0, 2) distance from home =  2
# (5, 1) distance from home =  6
# (1, 1) distance from home =  2
# (0, 2) distance from home =  2
# (2, -2) distance from home =  4
# (1, -1) distance from home =  2
# (3, -1) distance from home =  4
# (-1, 3) distance from home =  4
# (1, -3) distance from home =  4
# (4, 0) distance from home =  4
# (2, -4) distance from home =  6
# (-2, 2) distance from home =  4
# (-2, 2) distance from home =  4
# (0, 2) distance from home =  2
# (-2, 0) distance from home =  2

# %%
def improved_random_walk(n):
    x, y = 0, 0
    for i in range(n):
        # each of the following random choices represents a direction
        # represented as the change in x and y, e.g. north --> x += 0, y += 1
        (dx, dy) = random.choice([(0, 1), (0, -1), (1, 0), (-1, 0)])
        x += dx
        y += dy
    return x, y

# %%
for i in range(100):
    walk = improved_random_walk(10)
    print(walk, "distance from home = ", abs(walk[0]) + abs(walk[1]))
# Out:
# (1, -5) distance from home =  6
# (0, -2) distance from home =  2
# (0, -2) distance from home =  2
# (2, -2) distance from home =  4
# (1, 1) distance from home =  2
# (2, 2) distance from home =  4
# (-2, 2) distance from home =  4
# (-2, 0) distance from home =  2
# (-3, -1) distance from home =  4
# (1, 1) distance from home =  2
# (3, 1) distance from home =  4
# (3, -3) distance from home =  6
# (0, 2) distance from home =  2
# (1, -3) distance from home =  4
# (-1, 5) distance from home =  6
# (0, 2) distance from home =  2
# (-3, 1) distance from home =  4
# (2, 0) distance from home =  2
# (0, 2) distance from home =  2
# (0, 4) distance from home =  4
# (1, -1) distance from home =  2
# (-2, 2) distance from home =  4
# (-3, -1) distance from home =  4
# (1, 3) distance from home =  4
# (2, 6) distance from home =  8
# (0, 0) distance from home =  0
# (1, -1) distance from home =  2
# (-1, -5) distance from home =  6
# (0, -4) distance from home =  4
# (2, 2) distance from home =  4
# (-1, -1) distance from home =  2
# (0, 2) distance from home =  2
# (-1, 1) distance from home =  2
# (0, 2) distance from home =  2
# (1, 1) distance from home =  2
# (4, 0) distance from home =  4
# (-1, 1) distance from home =  2
# (-1, 3) distance from home =  4
# (2, 2) distance from home =  4
# (-2, -6) distance from home =  8
# (2, 2) distance from home =  4
# (-2, 0) distance from home =  2
# (0, -2) distance from home =  2
# (2, 2) distance from home =  4
# (0, 0) distance from home =  0
# (-1, 3) distance from home =  4
# (-1, -3) distance from home =  4
# (-2, 2) distance from home =  4
# (-2, -2) distance from home =  4
# (-1, -1) distance from home =  2
# (2, 0) distance from home =  2
# (-3, -3) distance from home =  6
# (1, 1) distance from home =  2
# (-3, -1) distance from home =  4
# (0, 2) distance from home =  2
# (0, 0) distance from home =  0
# (0, 0) distance from home =  0
# (-1, -1) distance from home =  2
# (-2, 2) distance from home =  4
# (-4, 0) distance from home =  4
# (-4, 2) distance from home =  6
# (2, 2) distance from home =  4
# (2, -2) distance from home =  4
# (-1, -3) distance from home =  4
# (2, -2) distance from home =  4
# (-1, -3) distance from home =  4
# (-1, -1) distance from home =  2
# (-1, -3) distance from home =  4
# (-1, 1) distance from home =  2
# (-1, -1) distance from home =  2
# (-1, 1) distance from home =  2
# (1, -1) distance from home =  2
# (-1, -1) distance from home =  2
# (0, 0) distance from home =  0
# (-3, -1) distance from home =  4
# (-2, -4) distance from home =  6
# (-1, -1) distance from home =  2
# (-3, 3) distance from home =  6
# (1, 1) distance from home =  2
# (0, 2) distance from home =  2
# (2, -2) distance from home =  4
# (-1, -5) distance from home =  6
# (0, 0) distance from home =  0
# (-1, -3) distance from home =  4
# (2, 0) distance from home =  2
# (-1, -1) distance from home =  2
# (3, 1) distance from home =  4
# (-4, 0) distance from home =  4
# (-2, 2) distance from home =  4
# (1, 1) distance from home =  2
# (5, -3) distance from home =  8
# (-3, -1) distance from home =  4
# (0, -2) distance from home =  2
# (-2, -2) distance from home =  4
# (-2, 0) distance from home =  2
# (0, 0) distance from home =  0
# (1, 3) distance from home =  4
# (4, -2) distance from home =  6
# (-1, 1) distance from home =  2
# (5, 1) distance from home =  6

# %%
# given a problem e.g. the maximum random walk such that on average
# the distance of the walk is less than some value k, can be completed
# by utilizing a monte carlo simulation

# num. of random walks for a given walk length
total_walks = 1000
# distance k, which will be used as the walk constraint
k = 4
# range of walk lengths that we will test
for walk_length in range(1, 31):
    # initialize variable to count the number of walks
    # less than or equal to the given value k, in distance from home
    max_k = 0
    for i in range(total_walks):
        walk = improved_random_walk(walk_length)
        distance = abs(walk[0]) + abs(walk[1])
        if distance <= k:
            max_k += 1
    if max_k >= total_walks / 2:
        print("for walks of distance {}, on average, the walk length was less than or equal to k = {}".format(walk_length, k))
    else: 
        print("for walks of distance {}, on average, the walk length was greater than k = {}".format(walk_length, k))
    print("for walks of distance {}, the number of walks less than length k was {}".format(walk_length, max_k))
# Out:
# for walks of distance 1, on average, the walk length was less than or equal to k = 4
# for walks of distance 1, the number of walks less than length k was 1000
# for walks of distance 2, on average, the walk length was less than or equal to k = 4
# for walks of distance 2, the number of walks less than length k was 1000
# for walks of distance 3, on average, the walk length was less than or equal to k = 4
# for walks of distance 3, the number of walks less than length k was 1000
# for walks of distance 4, on average, the walk length was less than or equal to k = 4
# for walks of distance 4, the number of walks less than length k was 1000
# for walks of distance 5, on average, the walk length was less than or equal to k = 4
# for walks of distance 5, the number of walks less than length k was 890
# for walks of distance 6, on average, the walk length was less than or equal to k = 4
# for walks of distance 6, the number of walks less than length k was 941
# for walks of distance 7, on average, the walk length was less than or equal to k = 4
# for walks of distance 7, the number of walks less than length k was 755
# for walks of distance 8, on average, the walk length was less than or equal to k = 4
# for walks of distance 8, the number of walks less than length k was 857
# for walks of distance 9, on average, the walk length was less than or equal to k = 4
# for walks of distance 9, the number of walks less than length k was 653
# for walks of distance 10, on average, the walk length was less than or equal to k = 4
# for walks of distance 10, the number of walks less than length k was 788
# for walks of distance 11, on average, the walk length was less than or equal to k = 4
# for walks of distance 11, the number of walks less than length k was 599
# for walks of distance 12, on average, the walk length was less than or equal to k = 4
# for walks of distance 12, the number of walks less than length k was 730
# for walks of distance 13, on average, the walk length was less than or equal to k = 4
# for walks of distance 13, the number of walks less than length k was 553
# for walks of distance 14, on average, the walk length was less than or equal to k = 4
# for walks of distance 14, the number of walks less than length k was 675
# for walks of distance 15, on average, the walk length was greater than k = 4
# for walks of distance 15, the number of walks less than length k was 477
# for walks of distance 16, on average, the walk length was less than or equal to k = 4
# for walks of distance 16, the number of walks less than length k was 623
# for walks of distance 17, on average, the walk length was greater than k = 4
# for walks of distance 17, the number of walks less than length k was 431
# for walks of distance 18, on average, the walk length was less than or equal to k = 4
# for walks of distance 18, the number of walks less than length k was 575
# for walks of distance 19, on average, the walk length was greater than k = 4
# for walks of distance 19, the number of walks less than length k was 397
# for walks of distance 20, on average, the walk length was less than or equal to k = 4
# for walks of distance 20, the number of walks less than length k was 525
# for walks of distance 21, on average, the walk length was greater than k = 4
# for walks of distance 21, the number of walks less than length k was 396
# for walks of distance 22, on average, the walk length was greater than k = 4
# for walks of distance 22, the number of walks less than length k was 479
# for walks of distance 23, on average, the walk length was greater than k = 4
# for walks of distance 23, the number of walks less than length k was 357
# for walks of distance 24, on average, the walk length was greater than k = 4
# for walks of distance 24, the number of walks less than length k was 460
# for walks of distance 25, on average, the walk length was greater than k = 4
# for walks of distance 25, the number of walks less than length k was 350
# for walks of distance 26, on average, the walk length was greater than k = 4
# for walks of distance 26, the number of walks less than length k was 478
# for walks of distance 27, on average, the walk length was greater than k = 4
# for walks of distance 27, the number of walks less than length k was 299
# for walks of distance 28, on average, the walk length was greater than k = 4
# for walks of distance 28, the number of walks less than length k was 426
# for walks of distance 29, on average, the walk length was greater than k = 4
# for walks of distance 29, the number of walks less than length k was 285
# for walks of distance 30, on average, the walk length was greater than k = 4
# for walks of distance 30, the number of walks less than length k was 401

# %%
import pandas as pd

retention_r = pd.read_csv('./monte_carlo_inputs/persistence_rates.csv')
# ['4yr_12', '4yr_23', '4yr_34', '4yr_grad', '2yr_12', '2yr_grad']
retention_r_bachelors = [
    retention_r['4yr_12'].values[0],
    retention_r['4yr_23'].values[0],
    retention_r['4yr_34'].values[0],
    retention_r['4yr_grad'].values[0],
]

retention_r_associates = [
    retention_r['2yr_12'].values[0],
    retention_r['2yr_grad'].values[0]
]


quantile_income = pd.read_csv('./monte_carlo_inputs/quantile_income.csv')
# headers: [25pct, 75pct, awd_lvl, major, median, n, years_after_grad]

#format the data
quantile_income = quantile_income.replace('Computer and Information Sciences and Support Services','cs')
quantile_income = quantile_income.replace('Engineering Technologies and Engineering-Related Fields','eng')
quantile_income = quantile_income.replace('Health Professions and Related Programs','heal')
quantile_income = quantile_income.replace('Bachelor\'s','Bachelors')
# majors: [cs, eng, heal, NaN]
# awd_lvl: [Associate, Bachelor's]

quantile_income['75pct'] =(quantile_income['75pct'].str[1:-1]).astype(float)*1000
quantile_income['25pct'] =(quantile_income['25pct'].str[1:-1]).astype(float)*1000

# uncomment to see the dataframe
quantile_income
# Out:
#       25pct     75pct       awd_lvl major      50pct        n  \
# 0   27000.0   49800.0     Associate    cs   37875.14   2492.0
# 1   29900.0   53600.0     Associate    cs   41132.45   2147.0
# 2   31600.0   56200.0     Associate    cs   43094.44   1685.0
# 3   33100.0   60900.0     Associate    cs   46751.76   1174.0
# 4   33400.0   63600.0     Associate    cs   46582.82    754.0
# 5   36100.0   65700.0     Associate    cs   47619.08    452.0
# 6   37100.0   70000.0     Associate    cs   51253.10    222.0
# 7   50400.0   89100.0     Bachelors    cs   67313.82   2426.0
# 8   57400.0   96000.0     Bachelors    cs   74887.17   1919.0
# 9   63200.0  105100.0     Bachelors    cs   82239.15   1429.0
# 10  68600.0  113100.0     Bachelors    cs   88867.81    987.0
# 11  72900.0  118600.0     Bachelors    cs   94906.09    657.0
# 12  76400.0  126100.0     Bachelors    cs  100604.50    400.0
# 13  82100.0  135400.0     Bachelors    cs  107289.70    199.0
# 14  31900.0   54400.0     Associate   eng   42434.76   1774.0
# 15  33400.0   59700.0     Associate   eng   45153.90   1507.0
# 16  35800.0   63600.0     Associate   eng   47834.29   1213.0
# 17  38300.0   67800.0     Associate   eng   51268.79    899.0
# 18  40500.0   68900.0     Associate   eng   53978.40    602.0
# 19  39800.0   71900.0     Associate   eng   54312.63    373.0
# 20  45500.0   76600.0     Associate   eng   60823.63    169.0
# 21  41500.0   64000.0     Bachelors   eng   54033.69   1053.0
# 22  47500.0   70200.0     Bachelors   eng   59952.01    919.0
# 23  51400.0   75900.0     Bachelors   eng   64354.82    787.0
# 24  56900.0   82600.0     Bachelors   eng   69379.05    637.0
# 25  60000.0   86800.0     Bachelors   eng   72693.12    463.0
# 26  64500.0   91000.0     Bachelors   eng   76298.94    310.0
# 27  71900.0   98200.0     Bachelors   eng   82449.94    141.0
# 28  34400.0   62400.0     Associate  heal   49765.71  17113.0
# 29  36400.0   65500.0     Associate  heal   52560.77  13933.0
# 30  37900.0   68000.0     Associate  heal   54433.25  10678.0
# 31  40200.0   70900.0     Associate  heal   56664.88   7791.0
# 32  42100.0   73500.0     Associate  heal   59075.19   5372.0
# 33  43700.0   77400.0     Associate  heal   62469.54   3366.0
# 34  46900.0   84200.0     Associate  heal   66458.15   1729.0
# 35  42900.0   72100.0     Bachelors  heal   60125.00   5838.0
# 36  45300.0   75600.0     Bachelors  heal   62476.23   4677.0
# 37  47700.0   79000.0     Bachelors  heal   64529.53   3544.0
# 38  48800.0   82100.0     Bachelors  heal   66446.85   2546.0
# 39  50200.0   84900.0     Bachelors  heal   67930.98   1732.0
# 40  51400.0   88000.0     Bachelors  heal   70313.05   1042.0
# 41  57000.0   96600.0     Bachelors  heal   74904.01    525.0
# 42      NaN       NaN  Some College   NaN   11000.00      NaN
# 43      NaN       NaN  Some College   NaN   14000.00      NaN
# 44      NaN       NaN  Some College   NaN   16000.00      NaN
# 45      NaN       NaN  Some College   NaN   19000.00      NaN
# 46      NaN       NaN  Some College   NaN   21000.00      NaN
# 47      NaN       NaN  Some College   NaN   23000.00      NaN
# 48      NaN       NaN  Some College   NaN   25000.00      NaN
#
#    Organization TTL  years_after_grad
# 0         Statewide                 1
# 1         Statewide                 2
# 2         Statewide                 3
# 3         Statewide                 4
# 4         Statewide                 5
# 5         Statewide                 6
# 6         Statewide                 7
# 7         Statewide                 1
# 8         Statewide                 2
# 9         Statewide                 3
# 10        Statewide                 4
# 11        Statewide                 5
# 12        Statewide                 6
# 13        Statewide                 7
# 14        Statewide                 1
# 15        Statewide                 2
# 16        Statewide                 3
# 17        Statewide                 4
# 18        Statewide                 5
# 19        Statewide                 6
# 20        Statewide                 7
# 21        Statewide                 1
# 22        Statewide                 2
# 23        Statewide                 3
# 24        Statewide                 4
# 25        Statewide                 5
# 26        Statewide                 6
# 27        Statewide                 7
# 28        Statewide                 1
# 29        Statewide                 2
# 30        Statewide                 3
# 31        Statewide                 4
# 32        Statewide                 5
# 33        Statewide                 6
# 34        Statewide                 7
# 35        Statewide                 1
# 36        Statewide                 2
# 37        Statewide                 3
# 38        Statewide                 4
# 39        Statewide                 5
# 40        Statewide                 6
# 41        Statewide                 7
# 42              NaN                 1
# 43              NaN                 2
# 44              NaN                 3
# 45              NaN                 4
# 46              NaN                 5
# 47              NaN                 6
# 48              NaN                 7

# %%
import numpy as np
from numpy.random import choice
# need to write a function that can take parameters for 
# all uncertain variables (retention rate, average earnings per student, # of scholarships alotted)
# and output the expected ROI

# tasks, plot the given retention rate data we have, determine appropriate means to randomize estimated retention
# rates for trials

# given expected career earnings for different STEM majors, we should eventually randomize allocation of scholarships
# to different majors, to determine average expected earnings per person

# account for retention rate uncertainty only

# basic problem: selecting 5 degree programs, to which we will all

def calculate_ROI(rates, scholarship_distribution):
    # given our expected retention rate, and how we allocate the scholarships
    # among N different degree programs, calculate and return ROI
    
    return None

def generate_random_scholarship_distributions(n):
    values = []
    limit = n
    while len(values) < limit:
        curr_values = []
        while n > 0 and len(curr_values) < 4:
            value = random.randint(1, int(n / 2))
            curr_values.append(value)
            n -= value
        if n > 0:
            curr_values.append(n)
        while len(curr_values) < 5:
            curr_values.append(0)
        values.append(curr_values)
    return values

def select_random_scholarship_distribution(values):
    return random.choice(values)

def generate_exp_retention(rate):
    # really just an arbitrary amount of randomness here. USING CLT this should be about right
    return np.random.normal(r,0.025,1)

generate_random_scholarship_distributions(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-6ab13550fa7e> in <module>
#      44     return np.random.normal(r,0.025,1)
#      45
# ---> 46 generate_random_scholarship_distributions(10)
#
# <ipython-input-36-6ab13550fa7e> in generate_random_scholarship_distributions(n)
#      27         curr_values = []
#      28         while n > 0 and len(curr_values) < 4:
# ---> 29             value = random.randint(1, int(n / 2))
#      30             curr_values.append(value)
#      31             n -= value
#
# C:\ProgramData\Anaconda3\lib\random.py in randint(self, a, b)
#     219         """
#     220
# --> 221         return self.randrange(a, b+1)
#     222
#     223     def _randbelow(self, n, int=int, maxsize=1<<BPF, type=type,
#
# C:\ProgramData\Anaconda3\lib\random.py in randrange(self, start, stop, step, _int)
#     197             return istart + self._randbelow(width)
#     198         if step == 1:
# --> 199             raise ValueError("empty range for randrange() (%d,%d, %d)" % (istart, istop, width))
#     200
#     201         # Non-unit step argument supplied.
#
# ValueError: empty range for randrange() (1,1, 0)

# %%
def monte_carlo(trials, scholarships, retention_rates, retention_weights):
    for i in range(trials):
        generate_random_scholarship_distributions(scholarships)
        generate_exp_retention(retention_rates, retention_weights)

# %%
# Try using a "walk" through 7 years after starting a career 
# Attempt at a basic version of a Markov Cahin Monte Carlo simulation
def calculate_ROI(bachelors, retention_rates):
    # bachelors = boolean: True if bachelors degree, False if associates
    income = 0
    cost = 0
    dropout = False
    graduated = False
    year_after_grad = 0
    year = 0
    while year_after_grad < 7:
        if graduated or dropout:
            year_after_grad += 1
        if bachelors:
            if not dropout:
                if year < 4:
                    cost += 4500
                    # dropout according to rates
                    if np.random.uniform(0,1,1) > retention_rates[year]:
                        dropout = True
                else:
                    graduated = True
                    year_after_grad += 1
                    temp_income = quantile_income[quantile_income['years_after_grad']==year_after_grad]
                    income += temp_income[temp_income['awd_lvl'] == 'Bachelors']['50pct'].values[0]
            else:
                # workaround for using pandas to read in csv data
                temp_income = quantile_income[quantile_income['years_after_grad']==year_after_grad]
                income += temp_income[temp_income['awd_lvl'] == 'Some College']['50pct'].values[0]
        else:
            if not dropout:
                if year < 2:
                    cost += 4500
                    # dropout according to rates
                    if np.random.uniform(0,1,1) > retention_rates[year]:
                        dropout = True
                else:
                    graduated = True
                    year_after_grad += 1
                    temp_income = quantile_income[quantile_income['years_after_grad']==year_after_grad]
                    income += temp_income[temp_income['awd_lvl'] == 'Associate']['50pct'].values[0]
            else:
                # workaround for using pandas to read in csv data
                temp_income = quantile_income[quantile_income['years_after_grad']==year_after_grad]
                income += temp_income[temp_income['awd_lvl'] == 'Some College']['50pct'].values[0]
        year += 1
    #print(f'income: {income}\tcost: {cost}')
    return (income,cost)

def generate_distribution():
    limit = 25000000
    scholarships = []
    cost = 0
    while cost < limit:
        choice = random.choice(['A','B'])
        scholarships.append(choice)
        if choice == 'A':
            cost += 4500*2
        else:
            cost += 4500*4
    return scholarships

def monte_carlo(n):
    results = []
    for i in range(0,n):
        income = 0
        cost = 0
        current = generate_distribution()
        for student in current:
            if student == 'B':
                (cur_income, cur_cost) = calculate_ROI(True, retention_r_bachelors)
                income += cur_income
                cost += cur_cost
            else:
                (cur_income, cur_cost) = calculate_ROI(True, retention_r_bachelors)
                income += cur_income
                cost += cur_cost
        results.append([current.count('B'), (income-cost)/cost])
    return results

results = monte_carlo(10)

# %%
import matplotlib.pyplot as plt
plt.scatter(*zip(*results))
